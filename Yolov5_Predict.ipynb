# %% [markdown]
# #Predict Images
# ----------------
# **Özgün Yargı**

# %%
# %pip install -q wandb
# Out:
#      |████████████████████████████████| 2.1MB 6.5MB/s
#      |████████████████████████████████| 163kB 43.3MB/s
#      |████████████████████████████████| 102kB 9.1MB/s
#      |████████████████████████████████| 133kB 45.9MB/s
#      |████████████████████████████████| 71kB 7.0MB/s
# ...

# %%
import wandb
run = wandb.init()
artifact = run.use_artifact('adriaen/YOLOv5/run_2z5muba5_model:v0', type='model')
artifact_dir = artifact.download()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.29<br/>
#                 Syncing run <strong style="color:#cdcd00">driven-sun-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/adriaen/uncategorized" target="_blank">https://wandb.ai/adriaen/uncategorized</a><br/>
#                 Run page: <a href="https://wandb.ai/adriaen/uncategorized/runs/2fjjfscm" target="_blank">https://wandb.ai/adriaen/uncategorized/runs/2fjjfscm</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210507_135400-2fjjfscm</code><br/><br/>
# wandb: Downloading large artifact run_2z5muba5_model:v0, 89.45MB. 1 files... Done. 0:0:0

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output 

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (CPU)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# data	    hubconf.py	README.md	  train.py	  weights
# detect.py   LICENSE	requirements.txt  tutorial.ipynb
# Dockerfile  models	test.py		  utils

# %%
# !python detect.py --weights /content/artifacts/run_2z5muba5_model:v0/best.pt --img 300 --conf 0.1 --source /content/gdrive/MyDrive/House_Numbers_300/images/validation/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=300, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/gdrive/MyDrive/House_Numbers_300/images/validation/', update=False, view_img=False, weights=['/content/artifacts/run_2z5muba5_model:v0/best.pt'])
# YOLOv5 🚀 v5.0-72-ge97d129 torch 1.8.1+cu101 CPU
#
# Fusing layers...
# Model Summary: 392 layers, 46649031 parameters, 0 gradients, 114.2 GFLOPS
# WARNING: --img-size 300 must be multiple of max stride 32, updating to 320
# image 1/385 /content/gdrive/MyDrive/House_Numbers_300/images/validation/1.png: 320x320 1 1, 1 9, Done. (0.755s)
# image 2/385 /content/gdrive/MyDrive/House_Numbers_300/images/validation/1000.png: 320x320 2 1s, 2 3s, Done. (0.635s)
# ...

# %%
Image(filename='runs/detect/exp/252.png', width=320)

# %%
# !ls /content/yolov5/runs/detect/exp
# Out:
# 1000.png  1220.png  1416.png  1637.png	1844.png  2062.png  2274.png  2476.png
# 1004.png  1223.png  1418.png  1638.png	1855.png  2067.png  227.png   2483.png
# 1006.png  1224.png  1424.png  1639.png	1860.png  2069.png  2281.png  2488.png
# 1008.png  1230.png  1432.png  1641.png	1862.png  206.png   2284.png  2490.png
# 1012.png  1234.png  1436.png  164.png	1866.png  2072.png  2287.png  2492.png
# 1014.png  1236.png  1444.png  1655.png	1867.png  2073.png  2292.png  2494.png
# 1015.png  1238.png  1448.png  1658.png	1869.png  2075.png  2295.png  2501.png
# 1018.png  1244.png  1456.png  165.png	1871.png  2077.png  2305.png  2502.png
# 101.png   1255.png  1457.png  1660.png	1872.png  2085.png  231.png   2512.png
# 1023.png  1259.png  1458.png  1662.png	1892.png  2087.png  2320.png  2513.png
# 1025.png  1260.png  1464.png  1666.png	1893.png  2093.png  2322.png  2517.png
# 1027.png  126.png   146.png   1667.png	1906.png  2096.png  2329.png  2520.png
# ...
