# %% [markdown]
# # Training of Yolov5
# ---------------------
# **Özgün Yargı**
#
# In this exercise, large version of YOLOv5 was the best model with mean average precision %83.3 (at 91th epoch). Colab was used. For the best performance, I applied 100 epochs to 320x320 image size. The training process was very fast. It was completed in 1 hour 51 minutes with. It was seen that changing the image size has an impact on accuracy of the model.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output 

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla T4)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 2.1MB 8.2MB/s
#      |████████████████████████████████| 133kB 51.3MB/s
#      |████████████████████████████████| 102kB 13.3MB/s
#      |████████████████████████████████| 163kB 38.1MB/s
#      |████████████████████████████████| 71kB 8.5MB/s
# ...
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !ls
# Out:
# data	    hubconf.py	README.md	  train.py	  weights
# detect.py   LICENSE	requirements.txt  tutorial.ipynb
# Dockerfile  models	test.py		  utils

# %%
#Yolov5l
# !python train.py --img 300 --batch 100 --epochs 100 --data /content/gdrive/MyDrive/yolo/yolov5/yolov5-master/House_Numbers_300.yaml --weights yolov5l.pt --name SVHN_yolo_300_100 --cfg models/yolov5l.yaml
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-70-g3ef3a95 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=100, bbox_interval=-1, bucket='', cache_images=False, cfg='models/yolov5l.yaml', data='/content/gdrive/MyDrive/yolo/yolov5/yolov5-master/House_Numbers_300.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[300, 300], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='SVHN_yolo_300_100', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/SVHN_yolo_300_1003', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=100, upload_dataset=False, weights='yolov5l.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
