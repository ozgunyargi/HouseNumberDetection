# %% [markdown]
# # Training of Yolov5
# -----------------
# **Özgün Yargı**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/yolo/yolov5/yolov5-master
# Out:
# /content/gdrive/MyDrive/yolo/yolov5/yolov5-master

# %%
# !python train.py --img 64 --batch 60 --epochs 100 --data SVHN_config.yaml --cfg models/yolov5s.yaml --name SVHN_yolo_100 --weights yolov5s.pt
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 2021-5-4 torch 1.8.1+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=60, bbox_interval=-1, bucket='', cache_images=False, cfg='models/yolov5s.yaml', data='SVHN_config.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[64, 64], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='SVHN_yolo_100', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/SVHN_yolo_100', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=60, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
